# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from sql_functions import get_dataframe

# %%
df_cancellations = get_dataframe('''select * 
                   from cgn_analytics_24_3.cancellations_per_day_2012_sandy''')

df_cancellations.tail(10)
# Out:
#     flight_date origin  total_flights  total_cancellations  \
# 478  2012-11-29    IAD            207                    2
# 479  2012-11-29    LGA            288                    1
# 480  2012-11-30    DCA            220                    3
# 481  2012-11-30    BWI            284                    0
# 482  2012-11-30    PHL            223                    1
# 483  2012-11-30    IAD            207                    0
# 484  2012-11-30    JFK            259                    0
# 485  2012-11-30    LGA            287                    2
# 486  2012-11-30    EWR            370                    1
# 487  2012-11-30    BOS            291                    1
#
#      cancellation_percentage
# 478                 0.966184
# 479                 0.347222
# 480                 1.363636
# 481                 0.000000
# 482                 0.448430
# 483                 0.000000
# 484                 0.000000
# 485                 0.696864
# 486                 0.270270
# 487                 0.343643

# %%
plt?

# %%
plt.figure(figsize=(20, 9))
sns.lineplot(data=df_cancellations, x='flight_date', y='cancellation_percentage', hue='origin', marker='o')
plt.xticks(df_cancellations.flight_date[::16], rotation=45)
plt.title('Flights cancellations October-November 2012')
plt.xlabel('Date')
plt.ylabel('Percentage of cancelled flights')
plt.legend(title= 'Origin Airport Code')
plt.grid(True)

plt.show()
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df_weather = get_dataframe('select * from cgn_analytics_24_3.weather_sandy')
df_weather.tail(10)
# Out:
#           date  tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun  \
# 234 2012-11-21   8.1   3.9  13.3   0.0   0.0   30.0   9.4  None  1022.3  None
# 235 2012-11-22   7.2   2.2  14.4   0.0   0.0    NaN   6.1  None  1023.4  None
# 236 2012-11-23   7.5   0.6  14.4   0.0   0.0    NaN   7.6  None  1013.8  None
# 237 2012-11-24   5.6   3.3  11.1   0.0   0.0  289.0  27.4  None  1010.9  None
# 238 2012-11-25   2.5  -1.1   5.0   0.0   0.0  250.0  17.6  None  1015.2  None
# 239 2012-11-26   4.3  -2.2  10.0   0.0   0.0    NaN   8.6  None  1020.7  None
# 240 2012-11-27   3.5   2.8   5.6  13.0   0.0    NaN  13.0  None  1023.8  None
# 241 2012-11-28   3.3  -0.6   5.6   0.0   0.0  311.0  14.0  None  1024.9  None
# 242 2012-11-29   3.5  -1.7   8.3   0.0   0.0  251.0  14.4  None  1028.4  None
# 243 2012-11-30   4.7  -1.1  10.0   0.0   0.0    NaN   7.2  None  1028.5  None
#
#     airport_code
# 234          PHL
# 235          PHL
# 236          PHL
# 237          PHL
# 238          PHL
# 239          PHL
# 240          PHL
# 241          PHL
# 242          PHL
# 243          PHL

# %%
df_weather.columns
# Out:
# Index(['date', 'tavg', 'tmin', 'tmax', 'prcp', 'snow', 'wdir', 'wspd', 'wpgt',
#        'pres', 'tsun', 'airport_code'],
#       dtype='object')

# %%
df_weather['airport_code'].unique()
# Out:
# array(['JFK', 'LGA', 'EWR', 'PHL'], dtype=object)
